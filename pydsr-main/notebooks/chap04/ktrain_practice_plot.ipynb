# %% [markdown]
# ## 실습 문제 1: 일차 함수
#
# 함수 f(x) = 2x + 1 을 구현하고 그래프를 그려보세요.
#
# - **요구사항:**
#     1. -5부터 5까지의 x 값에 대해 y 값을 계산하는 f_pure_python(x) 함수를 순수 Python으로 작성하세요. (힌트: range 와 리스트 사용)
#     2. 동일한 기능을 하는 f_numpy(x) 함수를 NumPy를 사용하여 작성하세요. (힌트: np.linspace 또는 np.arange, 벡터화 연산)
#     3. 두 함수로부터 얻은 (x, y) 점들을 Matplotlib을 사용하여 별도의 그래프로 그리세요. (힌트: plt.plot 사용)

# %%
def f_pure_python(X):
    return 2*X + 1

# %%
import matplotlib.pyplot as plt

x = list(range(-5, 6))
y = [f_pure_python(x1) for x1 in x]
plt.plot(x, y)
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
def f(x):
    return 2*x+1

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 11)
y = f(x)
plt.plot(x, y)

# %% [markdown]
# ## 실습 문제 2: 이차 함수 (다항 함수)
#
# 함수 f(x) = 2x^2 - 3x + 4 를 구현하고 그래프를 그려보세요.
#
# - **요구사항:**
#     1. -5부터 5까지의 x 값에 대해 y 값을 계산하는 함수를 순수 Python으로 작성하세요.
#     2. 동일한 기능을 하는 함수를 NumPy를 사용하여 작성하세요.
#     3. 두 함수로부터 얻은 결과를 Matplotlib으로 시각화하세요. x축, y축 레이블과 그래프 제목을 추가하세요. (힌트: plt.xlabel, plt.ylabel, plt.title 사용)

# %%
def f_pure_python(X):
    return 2*(X**2) - 3*X +4

# %%
import matplotlib.pyplot as plt

x = list(range(-5, 6))
y = [f_pure_python(x1) for x1 in x]
plt.plot(x, y)

# %%
def f(x):
    return 2*(x**2) - 3*x +4

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 6, 110)
y = f(x)
plt.plot(x, y)

# %% [markdown]
# ## 실습 문제 3: 삼각 함수 (Cosine)
#
# 함수 f(x) = cos(x) 를 구현하고 그래프를 그려보세요.
#
# - **요구사항:**
#     1. 0부터 2π (약 6.28) 까지의 x 값에 대해 y 값을 계산하는 함수를 순수 Python으로 작성하세요. (힌트: math.cos 사용, 라디안 단위 사용)
#     2. 동일한 기능을 하는 함수를 NumPy를 사용하여 작성하세요. (힌트: np.cos, np.pi, np.linspace)
#     3. 두 함수로부터 얻은 결과를 Matplotlib으로 시각화하세요.

# %%
import math

def f_pure_python(X):
    return math.cos(X)

# %%
x = [i / (11 - 1) * 2 * math.pi for i in range(11)]
y = [f_pure_python(x1) for x1 in x]
plt.grid()
plt.plot(x, y)

# %%
import numpy as np

def f(x):
    return np.cos(x)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2 * np.pi, 2 * np.pi, 110)
y = f(x)
plt.grid()
plt.plot(x, y)

# %% [markdown]
# ## 실습 문제 4: 지수 함수 (Exponential)
#
# 자연 상수 e의 거듭제곱 함수 f(x) = e^x 를 구현하고 그래프를 그려보세요. 이 함수는 AI에서 확률 계산 등에 사용될 수 있습니다.
#
# - **요구사항:**
#     1. 2부터 2까지의 x 값에 대해 y 값을 계산하는 함수를 순수 Python으로 작성하세요. (힌트: math.exp)
#     2. 동일한 기능을 하는 함수를 NumPy를 사용하여 작성하세요. (힌트: np.exp)
#     3. 두 함수로부터 얻은 결과를 Matplotlib으로 시각화하세요.

# %%
import math

def f_pure_python(X):
    return math.e**X

# %%
x = list(range(0, 3))
y = [f_pure_python(x1) for x1 in x]
plt.grid()
plt.plot(x, y)

# %%
import numpy as np

def f(x):
    return np.e**x

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 2, 30)
y = f(x)
plt.grid()
plt.plot(x, y)

# %% [markdown]
# ## 실습 문제 5: 로그 함수 (Logarithm)
#
# 자연 로그 함수 f(x) = ln(x) (밑이 e인 로그)를 구현하고 그래프를 그려보세요. 로그 함수는 지수 함수의 역함수로, 정보 이론이나 손실 함수 등에서 활용됩니다.
#
# - **요구사항:**
#     1. 0보다 크고 10 이하인 x 값에 대해 y 값을 계산하는 함수를 순수 Python으로 작성하세요. (힌트: math.log, x > 0 이어야 함)
#     2. 동일한 기능을 하는 함수를 NumPy를 사용하여 작성하세요. (힌트: np.log, 배열 요소별 적용 가능)
#     3. 두 함수로부터 얻은 결과를 Matplotlib으로 시각화하세요.

# %%
import math

def f_pure_python(X):
    return math.log(X)

# %%
x = list(range(1, 11))
y = [f_pure_python(x1) for x1 in x]
plt.grid()
plt.plot(x, y)

# %%
import numpy as np

def f(x):
    return np.log(x)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1, 10, 100)
y = f(x)
plt.grid()
plt.plot(x, y)

# %% [markdown]
# ## 실습 문제 6: 절대값 함수
#
# 함수 f(x) = |x| (절대값) 를 구현하고 그래프를 그려보세요. 절대값은 L1 손실 함수 등에서 사용됩니다.
#
# - **요구사항:**
#     1. -5부터 5까지의 x 값에 대해 절대값 함수 값을 계산하고 NumPy (np.abs)를 사용하여 구현하세요.
#     2. Matplotlib으로 그래프를 그리고, x축, y축 레이블과 제목("Absolute Value Function")을 추가하세요.

# %%
import math

def f_pure_python(X):
    return abs(X)

# %%
x = list(range(-5, 6))
y = [f_pure_python(x1) for x1 in x]
plt.grid()
plt.plot(x, y)

# %%
import numpy as np

def f(x):
    return np.abs(x)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 11)
y = f(x)
plt.grid()
plt.plot(x, y)

# %% [markdown]
# ## 실습 문제 7: 정규분포 확률 밀도 함수(PDF) 구현
#
# **설명**: NumPy와 같은 라이브러리는 정규분포 샘플링을 위한 편리한 함수를 제공하지만, 그 근간이 되는 확률 밀도 함수(PDF, Probability Density Function)를 직접 구현해보는 것은 개념을 이해하는 데 큰 도움이 됩니다. 이 실습에서는 정규분포의 PDF 공식을 코드로 직접 작성하고, 이 함수의 그래프가 실제 데이터 샘플의 분포와 일치하는지 시각적으로 확인합니다.
#
# $$f(x) = \frac{1}{\sigma\sqrt{2\pi}} \exp\!\Bigl(-\frac{(x-\mu)^2}{2\sigma^2}\Bigr)$$
#
#   - $\\mu$ : 평균 (mean)
#   - $ \\sigma\\ $: 표준편차 (standard deviation)
#
# **요구사항**:
#
#   - 주어진 정규분포 PDF 공식을 파이썬 코드로 변환하여 `f(x, mu, sigma)` 함수를 완성하세요. `np.pi`와 `np.exp`를 활용하면 편리합니다.
#   - 평균(`μ`) 0, 표준편차(`σ`) 1인 표준 정규분포의 PDF를 계산하도록 함수를 호출하세요.
#   - `np.random.normal`로 생성한 샘플 데이터의 히스토그램과 직접 구현한 `f(x)` 함수의 그래프를 함께 그려, 두 결과가 일치하는지 확인합니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x: np.ndarray, mu: float, sigma: float) -> np.ndarray:
  """
  정규분포의 확률 밀도 함수(PDF)를 계산합니다.
  x: 확률 변수 값(들)
  mu: 평균
  sigma: 표준편차
  """
  # TODO: 정규분포 PDF 공식을 코드로 구현하세요.
  return (1/sigma*np.sqrt(2*np.pi))*np.exp(-(x-mu)**2/2*sigma**2)


mu, sigma = 0, 1
x = np.linspace(-4, 4, 1000)
y = f(x, mu, sigma)

plt.plot(x, y)

# %%
# %pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu, sigma = 0, 1
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
y = norm.pdf(x, mu, sigma)
plt.plot(x, y)
plt.title('Normal Distribution')
# Out:
# Text(0.5, 1.0, 'Normal Distribution')

# %%
def f2(x):
    return x +1
x1 = np.linspace(-4,4,10)
y2 = f2(x1)

plt.plot(x,y, label = "normal", ls='--')
plt.scatter(x1,y2, label="linear", color = 'orange', marker='2')
plt.grid()
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
fig, ax = plt.subplots(1)
ax.plot(x,y)
ax.set_title('Normal Distribution')
# Out:
# Text(0.5, 1.0, 'Normal Distribution')
